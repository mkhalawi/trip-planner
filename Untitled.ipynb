# %%
import os
from agents.mcp import MCPServerStreamableHttp

WEATHER_MCP_URL = os.getenv("WEATHER_MCP_URL")
print(WEATHER_MCP_URL)
# Out:
# None

# %%
from agents.mcp import MCPServerStreamableHttp
print(1)
weather_mcp_server = MCPServerStreamableHttp(
    name="LocalWeatherMCP",
    params={"url": "http://127.0.0.1:8000"},
    cache_tools_list=True,
)
print(2)
await weather_mcp_server.connect()
print(3)
# Out:
# 1
# 2
# Error initializing MCP server: Session terminated
# ---------------------------------------------------------------------------
# McpError                                  Traceback (most recent call last)
# Cell In[2], line 9
#       3 weather_mcp_server = MCPServerStreamableHttp(
#       4     name="LocalWeatherMCP",
#       5     params={"url": "http://127.0.0.1:8000"},
#       6     cache_tools_list=True,
#       7 )
#       8 print(2)
# ----> 9 await weather_mcp_server.connect()
#      10 print(3)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\agents\mcp\server.py:277, in _MCPServerWithClientSession.connect(self)
#     266 read, write, *_ = transport
#     268 session = await self.exit_stack.enter_async_context(
#     269     ClientSession(
#     270         read,
#    (...)    275     )
#     276 )
# --> 277 server_result = await session.initialize()
#     278 self.server_initialize_result = server_result
#     279 self.session = session
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\mcp\client\session.py:151, in ClientSession.initialize(self)
#     139 elicitation = (
#     140     types.ElicitationCapability() if self._elicitation_callback is not _default_elicitation_callback else None
#     141 )
#     142 roots = (
#     143     # TODO: Should this be based on whether we
#     144     # _will_ send notifications, or only whether
#    (...)    148     else None
#     149 )
# --> 151 result = await self.send_request(
#     152     types.ClientRequest(
#     153         types.InitializeRequest(
#     154             method="initialize",
#     155             params=types.InitializeRequestParams(
#     156                 protocolVersion=types.LATEST_PROTOCOL_VERSION,
#     157                 capabilities=types.ClientCapabilities(
#     158                     sampling=sampling,
#     159                     elicitation=elicitation,
#     160                     experimental=None,
#     161                     roots=roots,
#     162                 ),
#     163                 clientInfo=self._client_info,
#     164             ),
#     165         )
#     166     ),
#     167     types.InitializeResult,
#     168 )
#     170 if result.protocolVersion not in SUPPORTED_PROTOCOL_VERSIONS:
#     171     raise RuntimeError(f"Unsupported protocol version from the server: {result.protocolVersion}")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\mcp\shared\session.py:286, in BaseSession.send_request(self, request, result_type, request_read_timeout_seconds, metadata, progress_callback)
#     274     raise McpError(
#     275         ErrorData(
#     276             code=httpx.codes.REQUEST_TIMEOUT,
#    (...)    282         )
#     283     )
#     285 if isinstance(response_or_error, JSONRPCError):
# --> 286     raise McpError(response_or_error.error)
#     287 else:
#     288     return result_type.model_validate(response_or_error.result)
#
# McpError: Session terminated
